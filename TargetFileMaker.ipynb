# %%
import pandas as pd
import numpy as np
import itertools

# %%
g_sequences = {}

# g_sequences[0] = ['13524232514' ,'35421252143',  '51423252413', '14325242135'] #Group 1 sequences
# g_sequences[1] = ['51423252413', '14325242135', '13524232514' ,'35421252143'] #Group 2 sequences

g_sequences[0] = ['13524232514' ,'54231251343',  '15423241351', '42531451342'] #Group 1 sequences
g_sequences[1] = ['15423241351', '42531451342', '13524232514' ,'54231251343'] #Group 2 sequences
g_sequences[2] = ['54231251343' ,'13524232514',  '15423241351', '42531451342'] # Group 3 sequences

sequences = ['13524232514' ,'54231251343',  '15423241351', '42531451342']
# generate all possible permutations of the 4 sequences
# while treating swaps of the last two positions as the same permutation
all_perms = itertools.permutations(sequences, 4)

unique_perms = []
seen = set()

g_sequences_seen = set()
for g_sequence in g_sequences.values():
    key = tuple(g_sequence[:2]) + tuple(sorted(g_sequence[2:]))  # ignore order of last two
    g_sequences_seen.add(key)

for perm in all_perms:
    key = perm[:2] + tuple(sorted(perm[2:]))  # ignore order of last two
    if key not in seen and key not in g_sequences_seen:
        seen.add(key)
        unique_perms.append(perm)


# ### add g_sequences as the first three elements of unique_perms
# unique_perms = list(g_sequences.values()) + unique_perms

print(f"Total unique permutations: {len(unique_perms)}")
for p in unique_perms:
    print(p)




# effector_seqs = [2, 0, 2, 0]
# fixed_dur_seqs = [0, 1, 0, 1]


fingers = ['1', '2', '3', '4', '5']
effectors = [0 , 2] # 0 for speech, 2 for right hand

iti = 2000 # msecs for inter-trial interval
execTime = 5000 # msecs for each trial maximum
# effector = 2 #left or right hand
precue_time = 2000 # msecs for precue time

total_sub_num = 20


num_familiarization_blocks = 1
num_pre_blocks = 3
num_post_blocks = 3
num_induction_blocks = 6

effector_symbols = ['#', '$']
# Out:
# Total unique permutations: 9
# ('13524232514', '15423241351', '54231251343', '42531451342')
# ('13524232514', '42531451342', '54231251343', '15423241351')
# ('54231251343', '15423241351', '13524232514', '42531451342')
# ('54231251343', '42531451342', '13524232514', '15423241351')
# ('15423241351', '13524232514', '54231251343', '42531451342')
# ('15423241351', '54231251343', '13524232514', '42531451342')
# ('42531451342', '13524232514', '54231251343', '15423241351')
# ('42531451342', '54231251343', '13524232514', '15423241351')
# ('42531451342', '15423241351', '13524232514', '54231251343')

# %%
def check_run(seq):
    #check runs of 3
    for pos in range(len(seq)- 2):
        if (int(seq[pos]) == int(seq[pos + 1]) + 1 and int(seq[pos+1]) == int(seq[pos+2]) + 1):
            return True
        if (int(seq[pos]) == int(seq[pos + 1]) - 1 and int(seq[pos+1]) == int(seq[pos+2]) - 1):
            return True
    
    #check double press
    
    for pos in range(len(seq) - 1):
        if(int(seq[pos]) == int(seq[pos+1])):
            return True


    for finger in fingers:
        if seq.count(finger) == 0:
            return True
        
    # each finger should be used at least twice
    for finger in fingers:
        if seq.count(finger) < 2:
            return True
        
        
    return False

# %%
import random
from collections import Counter

seqs = ['13524232514']
print("Generated sequence:", seqs[0])
num_seqs_to_generate = 3

for _ in range(num_seqs_to_generate):

    # Compute zero-order statistics (digit frequencies) for each sequence
    zero_orders = [Counter(seq) for seq in seqs]

    # Compute first-order statistics (transition frequencies) for each sequence
    first_orders = [Counter(zip(seq, seq[1:])) for seq in seqs]

    # Generate a new sequence that matches the statistics
    while True:
        new_seq = ''.join(random.choice('12345') for _ in range(11))
        if check_run(new_seq):
            continue
        new_zero = Counter(new_seq)
        new_first = Counter(zip(new_seq, new_seq[1:]))
        if new_zero not in zero_orders and new_first not in first_orders:
            break
    
    print("Generated sequence:", new_seq)
    # Add the new sequence to the list of sequences and their statistics
    seqs.append(new_seq)


# generate all zero order and first order stats of the seqs
zero_orders = [Counter(seq)for seq in seqs]
first_orders = [Counter(zip(seq, seq[1:])) for seq in seqs]
# sort them by digit or transition pair
print("Zero-order statistics (digit frequencies):")
for i, zero in enumerate(zero_orders):
    print(f"Sequence {i+1}: {dict(sorted(zero.items()))}")
print("\nFirst-order statistics (transition frequencies):")
for i, first in enumerate(first_orders):
    print(f"Sequence {i+1}: {dict(sorted(first.items()))}")
# Out:
# Generated sequence: 13524232514
# Generated sequence: 34215342531
# Generated sequence: 51341213245
# Generated sequence: 34253151452
# Zero-order statistics (digit frequencies):
# Sequence 1: {'1': 2, '2': 3, '3': 2, '4': 2, '5': 2}
# Sequence 2: {'1': 2, '2': 2, '3': 3, '4': 2, '5': 2}
# Sequence 3: {'1': 3, '2': 2, '3': 2, '4': 2, '5': 2}
# Sequence 4: {'1': 2, '2': 2, '3': 2, '4': 2, '5': 3}
#
# First-order statistics (transition frequencies):
# Sequence 1: {('1', '3'): 1, ('1', '4'): 1, ('2', '3'): 1, ('2', '4'): 1, ('2', '5'): 1, ('3', '2'): 1, ('3', '5'): 1, ('4', '2'): 1, ('5', '1'): 1, ('5', '2'): 1}
# Sequence 2: {('1', '5'): 1, ('2', '1'): 1, ('2', '5'): 1, ('3', '1'): 1, ('3', '4'): 2, ('4', '2'): 2, ('5', '3'): 2}
# Sequence 3: {('1', '2'): 1, ('1', '3'): 2, ('2', '1'): 1, ('2', '4'): 1, ('3', '2'): 1, ('3', '4'): 1, ('4', '1'): 1, ('4', '5'): 1, ('5', '1'): 1}
# ...

# %%
# ### target file headers: [subNum, group, effector, symbol, isTrain, seq, fixedDur, execTime, iti, precueTime]
# # effector = 2 for right hand, 0 for speech

# for sub in range(total_sub_num):
#     group = sub % 2
#     subNum = sub + 1
#     block_num = 1



#     ################### Familiarization  #######################
#     isTrain = 0
#     num_rep = 10
#     for _ in range(num_familiarization_blocks):
#         block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
#         for _ in range(num_rep):
#             while True:
#                 seq = ''.join(map(str, np.random.choice(range(1,6), size=11)))
#                 if not check_run(seq):
#                     break
#             effector = 0 # speech
#             symbol = '$' # symbol for speech
#             fixed_dur = 1 # fixed duration for speech
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)
        
#         for _ in range(num_rep):
#             while True:
#                 seq = ''.join(map(str, np.random.choice(range(1,6), size=11)))
#                 if not check_run(seq):
#                     break
#             effector = 2 # right hand
#             symbol = '#' # symbol for right hand
#             fixed_dur = 0 
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)
#         block = block.sample(frac=1).reset_index(drop = True)
#         block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')
#         block_num += 1
        

#     ################### preInduction  #######################
#     isTrain = 0
#     num_rep = 5
#     for _ in range(num_pre_blocks):
#         block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
#         for idx, seq in enumerate(g_sequences[group]):
#             effector = effector_seqs[idx]
#             symbol = effector_symbols[idx % 2]
#             fixed_dur = fixed_dur_seqs[idx]
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)
#         block = pd.concat([block] * num_rep, ignore_index=True)


#         # adding randoms speech 
#         for _ in range(num_rep):
#             while True:
#                 seq = ''.join(map(str, np.random.choice(range(1,6), size=11)))
#                 if not check_run(seq):
#                     break
#             effector = 0 # speech
#             symbol = '$' # symbol for speech
#             fixed_dur = 1 # fixed duration for speech
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)

#         # adding randoms right hand
#         for _ in range(num_rep):
#             while True:
#                 seq = ''.join(map(str, np.random.choice(range(1,6), size=11)))
#                 if not check_run(seq):
#                     break
#             effector = 2 # right hand
#             symbol = '#' # symbol for right hand
#             fixed_dur = 0
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)
        

#         block = block.sample(frac=1).reset_index(drop = True)
#         block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

#         block_num += 1

#     ####################  Induction  ######################
#     isTrain = 1
#     num_rep = 8
#     for _ in range(num_induction_blocks):
#         block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
#         for idx, seq in enumerate(g_sequences[group][:2]):
#             effector = effector_seqs[idx]
#             symbol = effector_symbols[idx % 2]
#             fixed_dur = fixed_dur_seqs[idx]
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)
#         block = pd.concat([block] * num_rep, ignore_index=True)

#         # adding randoms speech
#         for _ in range(num_rep):
#             while True:
#                 seq = ''.join(map(str, np.random.choice(range(1,6), size=11)))
#                 if not check_run(seq):
#                     break
#             effector = 0 # speech
#             symbol = '$' # symbol for speech
#             fixed_dur = 1 # fixed duration for speech
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)

#         # adding randoms right hand
#         for _ in range(num_rep):
#             while True:
#                 seq = ''.join(map(str, np.random.choice(range(1,6), size=11)))
#                 if not check_run(seq):
#                     break
#             effector = 2 # right hand
#             symbol = '#' # symbol for right hand
#             fixed_dur = 0
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)

#         block = block.sample(frac=1).reset_index(drop = True)
#         block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

#         block_num += 1



#     #################### Post Induction ###########################
#     isTrain = 0
#     num_rep = 5
#     for _ in range(num_pre_blocks):
#         block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
#         for idx, seq in enumerate(g_sequences[group]):
#             effector = effector_seqs[idx]
#             symbol = effector_symbols[idx % 2]
#             fixed_dur = fixed_dur_seqs[idx]
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)
#         block = pd.concat([block] * num_rep, ignore_index=True)


#         # adding randoms speech
#         for _ in range(num_rep):
#             while True:
#                 seq = ''.join(map(str, np.random.choice(range(1,6), size=11)))
#                 if not check_run(seq):
#                     break
#             effector = 0 # speech
#             symbol = '$' # symbol for speech
#             fixed_dur = 1 # fixed duration for speech
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)

#         # adding randoms right hand
#         for _ in range(num_rep):
#             while True:
#                 seq = ''.join(map(str, np.random.choice(range(1,6), size=11)))
#                 if not check_run(seq):
#                     break
#             effector = 2 # right hand
#             symbol = '#' # symbol for right hand
#             fixed_dur = 0
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)

#         block = block.sample(frac=1).reset_index(drop = True)
#         block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

#         block_num += 1

# %%
# ### target file headers: [subNum, group, effector, symbol, isTrain, seq, fixedDur, execTime, iti, precueTime]
# # effector = 2 for right hand, 0 for speech


# for sub in range(4, total_sub_num):
#     group = sub % 2
#     subNum = sub + 1
#     block_num = 1

#     ################### Familiarization  #######################
#     isTrain = 0
#     num_rep = 10
#     for _ in range(num_familiarization_blocks):
#         block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
#         for effector in effectors:
#             for _ in range(num_rep):
#                 while True:
#                     seq = ''.join(map(str, np.random.choice(range(1,6), size=11)))
#                     if not check_run(seq):
#                         break
#                 if effector == 0:
#                     symbol = '$' # symbol for speech
#                     fixed_dur = 1 # fixed duration for speech
#                 else:
#                     symbol = '#' # symbol for right hand
#                     fixed_dur = 0 
#                 trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#                 block = pd.concat([block, trial], ignore_index=True)

#         block = block.sample(frac=1).reset_index(drop = True)
#         block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')
#         block_num += 1
        

#     ################### preInduction  #######################
#     isTrain = 0
#     num_rep = 4
#     for _ in range(num_pre_blocks):
#         block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
#         for effector in effectors:
#             for idx, seq in enumerate(g_sequences[group]):
#                 if effector == 0:
#                     symbol = '$' # symbol for speech
#                     fixed_dur = 1 # fixed duration for speech
#                 else:
#                     symbol = '#' # symbol for right hand
#                     fixed_dur = 0 
#                 trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#                 block = pd.concat([block, trial], ignore_index=True)
#         block = pd.concat([block] * num_rep, ignore_index=True)
#         block = block.sample(frac=1).reset_index(drop = True)
#         block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

#         block_num += 1

#     ####################  Induction  ######################
#     isTrain = 1
#     num_rep = 16
#     for _ in range(num_induction_blocks):
#         block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
#         for idx, seq in enumerate(g_sequences[group][:2]):
#             effector = effectors[idx % 2]
#             if effector == 0:
#                 symbol = '$' # symbol for speech
#                 fixed_dur = 1 # fixed duration for speech
#             else:
#                 symbol = '#' # symbol for right hand
#                 fixed_dur = 0 
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)

#         block = pd.concat([block] * num_rep, ignore_index=True)
#         block = block.sample(frac=1).reset_index(drop = True)
#         block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

#         block_num += 1



#     #################### Post Induction ###########################
#     isTrain = 0
#     num_rep = 4
#     for _ in range(num_pre_blocks):
#         block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
#         for effector in effectors:
#             for idx, seq in enumerate(g_sequences[group]):
#                 if effector == 0:
#                     symbol = '$' # symbol for speech
#                     fixed_dur = 1 # fixed duration for speech
#                 else:
#                     symbol = '#' # symbol for right hand
#                     fixed_dur = 0 
#                 trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#                 block = pd.concat([block, trial], ignore_index=True)
#         block = pd.concat([block] * num_rep, ignore_index=True)
#         block = block.sample(frac=1).reset_index(drop = True)
#         block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

#         block_num += 1

# %%
# ### target file headers: [subNum, group, effector, symbol, isTrain, seq, fixedDur, execTime, iti, precueTime]
# # effector = 2 for right hand, 0 for speech


# for sub in range(8, 10):
#     group = 2
#     subNum = sub + 1
#     block_num = 1

#     ################### Familiarization  #######################
#     isTrain = 0
#     num_rep = 10
#     for _ in range(num_familiarization_blocks):
#         block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
#         for effector in effectors:
#             for _ in range(num_rep):
#                 while True:
#                     seq = ''.join(map(str, np.random.choice(range(1,6), size=11)))
#                     if not check_run(seq):
#                         break
#                 if effector == 0:
#                     symbol = '$' # symbol for speech
#                     fixed_dur = 1 # fixed duration for speech
#                 else:
#                     symbol = '#' # symbol for right hand
#                     fixed_dur = 0 
#                 trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#                 block = pd.concat([block, trial], ignore_index=True)

#         block = block.sample(frac=1).reset_index(drop = True)
#         block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')
#         block_num += 1
        

#     ################### preInduction  #######################
#     isTrain = 0
#     num_rep = 4
#     for _ in range(num_pre_blocks):
#         block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
#         for effector in effectors:
#             for idx, seq in enumerate(g_sequences[group]):
#                 if effector == 0:
#                     symbol = '$' # symbol for speech
#                     fixed_dur = 1 # fixed duration for speech
#                 else:
#                     symbol = '#' # symbol for right hand
#                     fixed_dur = 0 
#                 trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#                 block = pd.concat([block, trial], ignore_index=True)
#         block = pd.concat([block] * num_rep, ignore_index=True)
#         block = block.sample(frac=1).reset_index(drop = True)
#         block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

#         block_num += 1

#     ####################  Induction  ######################
#     isTrain = 1
#     num_rep = 16
#     for _ in range(num_induction_blocks):
#         block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
#         for idx, seq in enumerate(g_sequences[group][:2]):
#             effector = effectors[idx % 2]
#             if effector == 0:
#                 symbol = '$' # symbol for speech
#                 fixed_dur = 1 # fixed duration for speech
#             else:
#                 symbol = '#' # symbol for right hand
#                 fixed_dur = 0 
#             trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#             block = pd.concat([block, trial], ignore_index=True)

#         block = pd.concat([block] * num_rep, ignore_index=True)
#         block = block.sample(frac=1).reset_index(drop = True)
#         block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

#         block_num += 1



#     #################### Post Induction ###########################
#     isTrain = 0
#     num_rep = 4
#     for _ in range(num_pre_blocks):
#         block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
#         for effector in effectors:
#             for idx, seq in enumerate(g_sequences[group]):
#                 if effector == 0:
#                     symbol = '$' # symbol for speech
#                     fixed_dur = 1 # fixed duration for speech
#                 else:
#                     symbol = '#' # symbol for right hand
#                     fixed_dur = 0 
#                 trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
#                 block = pd.concat([block, trial], ignore_index=True)
#         block = pd.concat([block] * num_rep, ignore_index=True)
#         block = block.sample(frac=1).reset_index(drop = True)
#         block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

#         block_num += 1

# %%
### target file headers: [subNum, group, effector, symbol, isTrain, seq, fixedDur, execTime, iti, precueTime]
# effector = 2 for right hand, 0 for speech

for sub in range(10, total_sub_num):
    group = 3 + ((sub-1) % len(unique_perms))  # assign groups based on unique permutations
    subNum = sub + 1
    block_num = 1

    ################### Familiarization  #######################
    isTrain = 0
    num_rep = 10
    for _ in range(num_familiarization_blocks):
        block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
        for effector in effectors:
            for _ in range(num_rep):
                while True:
                    seq = ''.join(map(str, np.random.choice(range(1,6), size=11)))
                    if not check_run(seq):
                        break
                if effector == 0:
                    symbol = '$' # symbol for speech
                    fixed_dur = 1 # fixed duration for speech
                else:
                    symbol = '#' # symbol for right hand
                    fixed_dur = 0 
                trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
                block = pd.concat([block, trial], ignore_index=True)

        block = block.sample(frac=1).reset_index(drop = True)
        block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')
        block_num += 1
        

    ################### preInduction  #######################
    isTrain = 0
    num_rep = 4
    for _ in range(num_pre_blocks):
        block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
        for effector in effectors:
            for idx, seq in enumerate(unique_perms[group-3]):
                if effector == 0:
                    symbol = '$' # symbol for speech
                    fixed_dur = 1 # fixed duration for speech
                else:
                    symbol = '#' # symbol for right hand
                    fixed_dur = 0 
                trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
                block = pd.concat([block, trial], ignore_index=True)
        block = pd.concat([block] * num_rep, ignore_index=True)
        block = block.sample(frac=1).reset_index(drop = True)
        block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

        block_num += 1

    ####################  Induction  ######################
    isTrain = 1
    num_rep = 16
    for _ in range(num_induction_blocks):
        block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
        for idx, seq in enumerate(unique_perms[group-3][:2]):
            effector = effectors[idx % 2]
            if effector == 0:
                symbol = '$' # symbol for speech
                fixed_dur = 1 # fixed duration for speech
            else:
                symbol = '#' # symbol for right hand
                fixed_dur = 0 
            trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
            block = pd.concat([block, trial], ignore_index=True)

        block = pd.concat([block] * num_rep, ignore_index=True)
        block = block.sample(frac=1).reset_index(drop = True)
        block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

        block_num += 1



    #################### Post Induction ###########################
    isTrain = 0
    num_rep = 4
    for _ in range(num_pre_blocks):
        block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
        for effector in effectors:
            for idx, seq in enumerate(unique_perms[group-3]):
                if effector == 0:
                    symbol = '$' # symbol for speech
                    fixed_dur = 1 # fixed duration for speech
                else:
                    symbol = '#' # symbol for right hand
                    fixed_dur = 0 
                trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
                block = pd.concat([block, trial], ignore_index=True)
        block = pd.concat([block] * num_rep, ignore_index=True)
        block = block.sample(frac=1).reset_index(drop = True)
        block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

        block_num += 1

# %% [markdown]
# # Costumization for a participant:

# %%
execTime = 3000 # msecs for each trial maximum

# %%
### target file headers: [subNum, group, effector, symbol, isTrain, seq, fixedDur, execTime, iti, precueTime]
# effector = 2 for right hand, 0 for speech

sub = 2
group = sub % 2
subNum = sub + 1
block_num = 1

################### Familiarization  #######################
isTrain = 0
num_rep = 10
for _ in range(num_familiarization_blocks):
    block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
    for effector in effectors:
        for _ in range(num_rep):
            while True:
                seq = ''.join(map(str, np.random.choice(range(1,6), size=11)))
                if not check_run(seq):
                    break
            if effector == 0:
                symbol = '$' # symbol for speech
                fixed_dur = 1 # fixed duration for speech
            else:
                symbol = '#' # symbol for right hand
                fixed_dur = 0 
            trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
            block = pd.concat([block, trial], ignore_index=True)

    block = block.sample(frac=1).reset_index(drop = True)
    block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')
    block_num += 1
    

################### preInduction  #######################
isTrain = 0
num_rep = 4
for _ in range(num_pre_blocks):
    block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
    for effector in effectors:
        for idx, seq in enumerate(g_sequences[group]):
            if effector == 0:
                symbol = '$' # symbol for speech
                fixed_dur = 1 # fixed duration for speech
            else:
                symbol = '#' # symbol for right hand
                fixed_dur = 0 
            trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
            block = pd.concat([block, trial], ignore_index=True)
    block = pd.concat([block] * num_rep, ignore_index=True)
    block = block.sample(frac=1).reset_index(drop = True)
    block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

    block_num += 1

####################  Induction  ######################
isTrain = 1
num_rep = 8
for _ in range(num_induction_blocks):
    block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
    for effector in effectors:
        for idx, seq in enumerate(g_sequences[group][:2]):
            if effector == 0:
                symbol = '$' # symbol for speech
                fixed_dur = 1 # fixed duration for speech
            else:
                symbol = '#' # symbol for right hand
                fixed_dur = 0 
            trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
            block = pd.concat([block, trial], ignore_index=True)

    block = pd.concat([block] * num_rep, ignore_index=True)
    block = block.sample(frac=1).reset_index(drop = True)
    block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

    block_num += 1



#################### Post Induction ###########################
isTrain = 0
num_rep = 4
for _ in range(num_pre_blocks):
    block = pd.DataFrame(columns=["subNum", "group", "effector", "symbol", "isTrain", "seq", "fixedDur", "execTime", "iti", "precueTime"])
    for effector in effectors:
        for idx, seq in enumerate(g_sequences[group]):
            if effector == 0:
                symbol = '$' # symbol for speech
                fixed_dur = 1 # fixed duration for speech
            else:
                symbol = '#' # symbol for right hand
                fixed_dur = 0 
            trial  = pd.DataFrame([[subNum, group, effector, symbol, isTrain, seq, fixed_dur, execTime, iti, precue_time]], columns = block.columns)
            block = pd.concat([block, trial], ignore_index=True)
    block = pd.concat([block] * num_rep, ignore_index=True)
    block = block.sample(frac=1).reset_index(drop = True)
    block.to_csv(f'SFS1_subj{subNum}_group{group+1}_block{block_num}.tgt', index=False, sep='\t')

    block_num += 1
